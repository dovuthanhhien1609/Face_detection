# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pwd
# Out:
# '/content'

# %%
cd /content/drive/MyDrive/AI
# Out:
# /content/drive/MyDrive/AI

# %%
# !git clone https://github.com/biubug6/Pytorch_Retinaface.git

# %%
cd Pytorch_Retinaface
# Out:
# /content/drive/MyDrive/AI/Pytorch_Retinaface

# %%
# !CUDA_VISIBLE_DEVICES=0 python train.py --network mobile0.25
# Out:
# Streaming output truncated to the last 5000 lines.
# Epoch:8/20 || Epochiter: 240/403 || Iter: 3061/8060 || Loc: 1.2420 Cla: 1.8137 Landm: 3.2887 || LR: 0.00100000 || Batchtime: 0.6761 s || ETA: 0:56:20
# Epoch:8/20 || Epochiter: 241/403 || Iter: 3062/8060 || Loc: 0.8732 Cla: 1.4693 Landm: 3.3401 || LR: 0.00100000 || Batchtime: 0.6699 s || ETA: 0:55:48
# Epoch:8/20 || Epochiter: 242/403 || Iter: 3063/8060 || Loc: 1.1562 Cla: 1.7374 Landm: 2.8447 || LR: 0.00100000 || Batchtime: 1.0610 s || ETA: 1:28:23
# Epoch:8/20 || Epochiter: 243/403 || Iter: 3064/8060 || Loc: 1.7406 Cla: 2.0998 Landm: 4.9979 || LR: 0.00100000 || Batchtime: 2.4880 s || ETA: 3:27:12
# Epoch:8/20 || Epochiter: 244/403 || Iter: 3065/8060 || Loc: 1.1406 Cla: 1.7017 Landm: 4.3853 || LR: 0.00100000 || Batchtime: 0.5690 s || ETA: 0:47:22
# Epoch:8/20 || Epochiter: 245/403 || Iter: 3066/8060 || Loc: 1.0814 Cla: 1.5054 Landm: 3.1544 || LR: 0.00100000 || Batchtime: 0.6290 s || ETA: 0:52:21
# ...

# %%
cd /content/drive/MyDrive/AI/Pytorch_Retinaface
# Out:
# /content/drive/MyDrive/AI/Pytorch_Retinaface

# %%
# !python test_widerface.py --trained_model /content/drive/MyDrive/AI/Pytorch_Retinaface/weights/mobilenet0.25_Final.pth --network mobile0.25
# Out:
# Loading pretrained model from /content/drive/MyDrive/AI/Pytorch_Retinaface/weights/mobilenet0.25_Final.pth
# remove prefix 'module.'
# Missing keys:0
# Unused checkpoint keys:0
# Used keys:300
# Finished loading model!
# RetinaFace(
#   (body): IntermediateLayerGetter(
#     (stage1): Sequential(
#       (0): Sequential(
#         (0): Conv2d(3, 8, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1, inplace=True)
#       )
#       (1): Sequential(
#         (0): Conv2d(8, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=8, bias=False)
#         (1): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1, inplace=True)
#         (3): Conv2d(8, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
# ...
